# %% [markdown]
# **Nadia Dwi Swastiti - 10117099**
#
# minimumkan
# $$f(x_1,x_2,x_3)=x_1^2+5x_2^2+25x_3^2-x_1-x_2-x_3$$
# bentuk lain
# $$f(x_1,x_2,x_3)=\begin{bmatrix} x_1&x_2&x_3 \end{bmatrix}\begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 5 & 0 \\
# 0 & 0 & 25 \end{bmatrix}\begin{bmatrix} x_1\\x_2\\x_3\end{bmatrix}-\begin{bmatrix} 1&1&1 \end{bmatrix}\begin{bmatrix} x_1\\x_2\\x_3 \end{bmatrix}$$
# $$\nabla f(x)=\begin{bmatrix} 2x_1-1\\10x_2-1\\50x_3-1 \end{bmatrix}$$
# $$\nabla^2f(x)=\begin{bmatrix} 2&0&0\\0&10&0\\0&0&50 \end{bmatrix}$$

# %%
import numpy as np

# %%
#Metode Steepest Descent

x=np.array([0,0,1]) #nilai awal
print("x0= ",x)
nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1]) #menghitung nabla f(x) dengan x awal
Q=np.array([[2,0,0],[0,10,0],[0,0,50]])
print("nabla f(x0)= ",nablaf)
print("norm(nabla f(x0))= ",np.linalg.norm(nablaf))
error=0.00001

iter=1
maxiter=100

while np.linalg.norm(nablaf)>error and iter<maxiter:
  alpha=(nablaf@nablaf)/(nablaf@Q@nablaf)
  x=x-alpha*nablaf
  print("\n","x",iter,"=",x)
  nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1])
  print("nabla f(x",iter,")= ",nablaf)
  print("norm(nabla f(x",iter,")= ",np.linalg.norm(nablaf))
  iter=iter+1
# Out:
# x0=  [0 0 1]
# nabla f(x0)=  [-1 -1 49]
# norm(nabla f(x0))=  49.02040391510457
#
#  x 1 = [0.02001466 0.02001466 0.0192817 ]
# nabla f(x 1 )=  [-0.95997068 -0.79985341 -0.03591478]
# norm(nabla f(x 1 )=  1.2500396222442083
#
#  x 2 = [0.20062955 0.17050409 0.02603894]
# nabla f(x 2 )=  [-0.59874089  0.70504088  0.30194678]
# norm(nabla f(x 2 )=  0.9730083005462088
#
#  x 3 = [ 0.25595191  0.10535984 -0.00186029]
# nabla f(x 3 )=  [-0.48809618  0.05359842 -1.09301454]
# norm(nabla f(x 3 )=  1.198245155362977
#
#  x 4 = [0.2675856  0.10408233 0.02419151]
# nabla f(x 4 )=  [-0.46482881  0.04082334  0.20957565]
# norm(nabla f(x 4 )=  0.5115215709359103
#
#  x 5 = [0.31357021 0.10004376 0.0034586 ]
# nabla f(x 5 )=  [-3.72859578e-01  4.37599080e-04 -8.27070031e-01]
# norm(nabla f(x 5 )=  0.9072316638688546
#
#  x 6 = [0.32247064 0.10003331 0.02320135]
# nabla f(x 6 )=  [-3.55058727e-01  3.33141043e-04  1.60067694e-01]
# norm(nabla f(x 6 )=  0.3894720494255534
#
#  x 7 = [0.35759827 0.10000035 0.0073651 ]
# nabla f(x 7 )=  [-2.84803456e-01  3.54888699e-06 -6.31744926e-01]
# norm(nabla f(x 7 )=  0.6929752234076502
#
#  x 8 = [0.36439674 0.10000027 0.02244531]
# nabla f(x 8 )=  [-2.71206528e-01  2.70174208e-06  1.22265417e-01]
# norm(nabla f(x 8 )=  0.29749254284955545
#
#  x 9 = [0.39122848 0.1        0.01034901]
# nabla f(x 9 )=  [-2.17543044e-01  2.87811144e-08 -4.82549322e-01]
# norm(nabla f(x 9 )=  0.5293192080064252
#
#  x 10 = [0.39642139 0.1        0.02186781]
# nabla f(x 10 )=  [-2.07157226e-01  2.19108549e-08  9.33906888e-02]
# norm(nabla f(x 10 )=  0.227235421789052
#
#  x 11 = [0.41691643 0.1        0.01262823]
# nabla f(x 11 )=  [-1.66167141e-01  2.33411956e-10 -3.68588394e-01]
# norm(nabla f(x 11 )=  0.4043129025865121
#
#  x 12 = [0.42088296 0.1        0.0214267 ]
# nabla f(x 12 )=  [-1.58234082e-01  1.77694748e-10  7.13351412e-02]
# norm(nabla f(x 12 )=  0.1735705252413349
#
#  x 13 = [0.4365378  0.1        0.01436918]
# nabla f(x 13 )=  [-1.26924393e-01  1.89315230e-12 -2.81540970e-01]
# norm(nabla f(x 13 )=  0.30882862500608166
#
#  x 14 = [0.43956758 0.1        0.02108977]
# nabla f(x 14 )=  [-1.20864840e-01  1.44129153e-12  5.44883268e-02]
# norm(nabla f(x 14 )=  0.13257936194701347
#
#  x 15 = [0.45152531 0.1        0.01569898]
# nabla f(x 15 )=  [-9.69493814e-02  1.53210777e-14 -2.15051041e-01]
# norm(nabla f(x 15 )=  0.23589432593667797
#
#  x 16 = [0.45383956 0.1        0.0208324 ]
# nabla f(x 16 )=  [-9.23208782e-02  1.17683641e-14  4.16201287e-02]
# norm(nabla f(x 16 )=  0.10126884843977686
#
#  x 17 = [0.4629733  0.1        0.01671473]
# nabla f(x 17 )=  [-0.0740534   0.         -0.16426366]
# norm(nabla f(x 17 )=  0.18018450526735943
#
#  x 18 = [0.46474101 0.1        0.02063582]
# nabla f(x 18 )=  [-0.07051798  0.          0.03179094]
# norm(nabla f(x 18 )=  0.077352760744294
#
#  x 19 = [0.47171769 0.1        0.01749059]
# nabla f(x 19 )=  [-0.05656463  0.         -0.12547045]
# norm(nabla f(x 19 )=  0.13763135594519596
#
#  x 20 = [0.47306792 0.1        0.02048566]
# nabla f(x 20 )=  [-0.05386415  0.          0.02428305]
# norm(nabla f(x 20 )=  0.059084799392404026
#
#  x 21 = [0.47839696 0.1        0.01808322]
# nabla f(x 21 )=  [-0.04320608  0.         -0.09583881]
# norm(nabla f(x 21 )=  0.10512774176229149
#
#  x 22 = [0.47942832 0.1        0.02037097]
# nabla f(x 22 )=  [-0.04114336  0.          0.01854826]
# norm(nabla f(x 22 )=  0.045131078524539306
#
#  x 23 = [0.48349883 0.1        0.0185359 ]
# nabla f(x 23 )=  [-0.03300235  0.         -0.0732051 ]
# norm(nabla f(x 23 )=  0.08030032118872577
#
#  x 24 = [0.48428662 0.1        0.02028336]
# nabla f(x 24 )=  [-0.03142677  0.          0.01416783]
# norm(nabla f(x 24 )=  0.03447272851450156
#
#  x 25 = [0.48739581 0.1        0.01888167]
# nabla f(x 25 )=  [-0.02520837  0.         -0.05591667]
# norm(nabla f(x 25 )=  0.061336251258898855
#
#  x 26 = [0.48799756 0.1        0.02021644]
# nabla f(x 26 )=  [-0.02400489  0.          0.01082189]
# norm(nabla f(x 26 )=  0.026331500378134556
#
#  x 27 = [0.49037247 0.1        0.01914578]
# nabla f(x 27 )=  [-0.01925505  0.         -0.04271115]
# norm(nabla f(x 27 )=  0.04685081781494669
#
#  x 28 = [0.49083211 0.1        0.02016532]
# nabla f(x 28 )=  [-0.01833579  0.          0.00826615]
# norm(nabla f(x 28 )=  0.020112939765473892
#
#  x 29 = [0.49264615 0.1        0.01934751]
# nabla f(x 29 )=  [-0.0147077  0.        -0.0326243]
# norm(nabla f(x 29 )=  0.03578632676236295
#
#  x 30 = [0.49299723 0.1        0.02012628]
# nabla f(x 30 )=  [-0.01400553  0.          0.00631398]
# norm(nabla f(x 30 )=  0.015362981227818704
#
#  x 31 = [0.49438287 0.1        0.01950161]
# nabla f(x 31 )=  [-0.01123426  0.         -0.0249196 ]
# norm(nabla f(x 31 )=  0.02733487360244231
#
#  x 32 = [0.49465104 0.1        0.02009646]
# nabla f(x 32 )=  [-0.01069792  0.          0.00482284]
# norm(nabla f(x 32 )=  0.01173479336976217
#
#  x 33 = [0.49570943 0.1        0.01961931]
# nabla f(x 33 )=  [-0.00858113  0.         -0.01903448]
# norm(nabla f(x 33 )=  0.020879352044796646
#
#  x 34 = [0.49591427 0.1        0.02007368]
# nabla f(x 34 )=  [-0.00817146  0.          0.00368386]
# norm(nabla f(x 34 )=  0.008963453993009097
#
#  x 35 = [0.49672271 0.1        0.01970922]
# nabla f(x 35 )=  [-0.00655457  0.         -0.01453922]
# norm(nabla f(x 35 )=  0.015948394280176907
#
#  x 36 = [0.49687918 0.1        0.02005628]
# nabla f(x 36 )=  [-0.00624165  0.          0.00281386]
# norm(nabla f(x 36 )=  0.006846606067373678
#
#  x 37 = [0.49749669 0.1        0.01977789]
# nabla f(x 37 )=  [-0.00500662  0.         -0.01110557]
# norm(nabla f(x 37 )=  0.012181952752665644
#
#  x 38 = [0.4976162  0.1        0.02004299]
# nabla f(x 38 )=  [-0.00476759  0.          0.00214933]
# norm(nabla f(x 38 )=  0.005229682071036389
#
#  x 39 = [0.49808788 0.1        0.01983034]
# nabla f(x 39 )=  [-0.00382423  0.         -0.00848283]
# norm(nabla f(x 39 )=  0.009305010288880892
#
#  x 40 = [0.49817917 0.1        0.02003283]
# nabla f(x 40 )=  [-0.00364166  0.          0.00164173]
# norm(nabla f(x 40 )=  0.003994617814284398
#
#  x 41 = [0.49853946 0.1        0.01987041]
# nabla f(x 41 )=  [-0.00292109  0.         -0.00647949]
# norm(nabla f(x 41 )=  0.0071074989563748555
#
#  x 42 = [0.49860919 0.1        0.02002508]
# nabla f(x 42 )=  [-0.00278163  0.          0.00125401]
# norm(nabla f(x 42 )=  0.0030512316552804533
#
#  x 43 = [0.49888439 0.1        0.01990101]
# nabla f(x 43 )=  [-0.00223123  0.         -0.00494927]
# norm(nabla f(x 43 )=  0.005428961370976026
#
#  x 44 = [0.49893765 0.1        0.02001916]
# nabla f(x 44 )=  [-0.00212471  0.          0.00095786]
# norm(nabla f(x 44 )=  0.0023306396373874777
#
#  x 45 = [0.49914785 0.1        0.01992439]
# nabla f(x 45 )=  [-0.00170429  0.         -0.00378043]
# norm(nabla f(x 45 )=  0.004146834455897701
#
#  x 46 = [0.49918854 0.1        0.02001463]
# nabla f(x 46 )=  [-0.00162293  0.          0.00073165]
# norm(nabla f(x 46 )=  0.0017802257360436296
#
#  x 47 = [0.4993491  0.1        0.01994225]
# nabla f(x 47 )=  [-0.0013018   0.         -0.00288762]
# norm(nabla f(x 47 )=  0.003167500158787725
#
#  x 48 = [0.49938018 0.1        0.02001118]
# nabla f(x 48 )=  [-0.00123965  0.          0.00055886]
# norm(nabla f(x 48 )=  0.0013597999538122448
#
#  x 49 = [0.49950282 0.1        0.01995589]
# nabla f(x 49 )=  [-0.00099436  0.         -0.00220567]
# norm(nabla f(x 49 )=  0.0024194496700126857
#
#  x 50 = [0.49952656 0.1        0.02000854]
# nabla f(x 50 )=  [-0.00094689  0.          0.00042688]
# norm(nabla f(x 50 )=  0.0010386637362613917
#
#  x 51 = [0.49962024 0.1        0.0199663 ]
# nabla f(x 51 )=  [-0.00075953  0.         -0.00168477]
# norm(nabla f(x 51 )=  0.0018480620086112958
#
#  x 52 = [0.49963837 0.1        0.02000652]
# nabla f(x 52 )=  [-0.00072327  0.          0.00032606]
# norm(nabla f(x 52 )=  0.000793368431878563
#
#  x 53 = [0.49970992 0.1        0.01997426]
# nabla f(x 53 )=  [-0.00058015  0.         -0.00128689]
# norm(nabla f(x 53 )=  0.0014116157198897994
#
#  x 54 = [0.49972377 0.1        0.02000498]
# nabla f(x 54 )=  [-0.00055246  0.          0.00024906]
# norm(nabla f(x 54 )=  0.0006060031237512164
#
#  x 55 = [0.49977843 0.1        0.01998034]
# nabla f(x 55 )=  [-0.00044314  0.         -0.00098297]
# norm(nabla f(x 55 )=  0.0010782424677070223
#
#  x 56 = [0.49978901 0.1        0.0200038 ]
# nabla f(x 56 )=  [-0.00042199  0.          0.00019024]
# norm(nabla f(x 56 )=  0.0004628868142972285
#
#  x 57 = [0.49983076 0.1        0.01998498]
# nabla f(x 57 )=  [-0.00033849  0.         -0.00075083]
# norm(nabla f(x 57 )=  0.0008236000795297809
#
#  x 58 = [0.49983884 0.1        0.02000291]
# nabla f(x 58 )=  [-0.00032233  0.          0.00014531]
# norm(nabla f(x 58 )=  0.0003535694692857149
#
#  x 59 = [0.49987073 0.1        0.01998853]
# nabla f(x 59 )=  [-0.00025855  0.         -0.00057351]
# norm(nabla f(x 59 )=  0.0006290951352007449
#
#  x 60 = [0.4998769  0.1        0.02000222]
# nabla f(x 60 )=  [-0.00024621  0.          0.00011099]
# norm(nabla f(x 60 )=  0.00027006897960745883
#
#  x 61 = [0.49990126 0.1        0.01999124]
# nabla f(x 61 )=  [-0.00019749  0.         -0.00043807]
# norm(nabla f(x 61 )=  0.0004805253168011329
#
#  x 62 = [0.49990597 0.1        0.0200017 ]
# nabla f(x 62 )=  [-1.88060985e-04  0.00000000e+00  8.47817152e-05]
# norm(nabla f(x 62 )=  0.00020628832544146192
#
#  x 63 = [0.49992458 0.1        0.01999331]
# nabla f(x 63 )=  [-0.00015085  0.         -0.00033461]
# norm(nabla f(x 63 )=  0.0003670423870202162
#
#  x 64 = [0.49992818 0.1        0.0200013 ]
# nabla f(x 64 )=  [-1.43647692e-04  0.00000000e+00  6.47592999e-05]
# norm(nabla f(x 64 )=  0.00015757038544478958
#
#  x 65 = [0.49994239 0.1        0.01999489]
# nabla f(x 65 )=  [-0.00011522  0.         -0.00025559]
# norm(nabla f(x 65 )=  0.000280360075024024
#
#  x 66 = [0.49994514 0.1        0.02000099]
# nabla f(x 66 )=  [-1.09723234e-04  0.00000000e+00  4.94654646e-05]
# norm(nabla f(x 66 )=  0.00012035788412215163
#
#  x 67 = [0.49995599 0.1        0.0199961 ]
# nabla f(x 67 )=  [-8.80123591e-05  0.00000000e+00 -1.95227130e-04]
# norm(nabla f(x 67 )=  0.00021414903141196332
#
#  x 68 = [0.49995809 0.1        0.02000076]
# nabla f(x 68 )=  [-8.38105222e-05  0.00000000e+00  3.77834873e-05]
# norm(nabla f(x 68 )=  9.193364749003162e-05
#
#  x 69 = [0.49996639 0.1        0.01999702]
# nabla f(x 69 )=  [-6.72269811e-05  0.00000000e+00 -1.49121450e-04]
# norm(nabla f(x 69 )=  0.00016357467321545253
#
#  x 70 = [0.49996799 0.1        0.02000058]
# nabla f(x 70 )=  [-6.40174681e-05  0.00000000e+00  2.88603761e-05]
# norm(nabla f(x 70 )=  7.02222010836079e-05
#
#  x 71 = [0.49997432 0.1        0.01999772]
# nabla f(x 71 )=  [-5.13503675e-05  0.00000000e+00 -1.13904285e-04]
# norm(nabla f(x 71 )=  0.00012494417341524247
#
#  x 72 = [0.49997555 0.1        0.02000044]
# nabla f(x 72 )=  [-4.88988269e-05  0.00000000e+00  2.20445853e-05]
# norm(nabla f(x 72 )=  5.3638223432511313e-05
#
#  x 73 = [0.49998039 0.1        0.01999826]
# nabla f(x 73 )=  [-3.92232434e-05  0.00000000e+00 -8.70041584e-05]
# norm(nabla f(x 73 )=  9.543681893784347e-05
#
#  x 74 = [0.49998132 0.1        0.02000034]
# nabla f(x 74 )=  [-3.73506692e-05  0.00000000e+00  1.68384410e-05]
# norm(nabla f(x 74 )=  4.097078941697181e-05
#
#  x 75 = [0.49998502 0.1        0.01999867]
# nabla f(x 75 )=  [-2.99601132e-05  0.00000000e+00 -6.64568814e-05]
# norm(nabla f(x 75 )=  7.289804846430876e-05
#
#  x 76 = [0.49998574 0.1        0.02000026]
# nabla f(x 76 )=  [-2.85297742e-05  0.00000000e+00  1.28618022e-05]
# norm(nabla f(x 76 )=  3.129495121247939e-05
#
#  x 77 = [0.49998856 0.1        0.01999898]
# nabla f(x 77 )=  [-2.28846037e-05  0.00000000e+00 -5.07621379e-05]
# norm(nabla f(x 77 )=  5.568213116323485e-05
#
#  x 78 = [0.4999891 0.1       0.0200002]
# nabla f(x 78 )=  [-2.17920598e-05  0.00000000e+00  9.82430357e-06]
# norm(nabla f(x 78 )=  2.390420065918594e-05
#
#  x 79 = [0.49999126 0.1        0.01999922]
# nabla f(x 79 )=  [-1.74800771e-05  0.00000000e+00 -3.87739326e-05]
# norm(nabla f(x 79 )=  4.2531999089371445e-05
#
#  x 80 = [0.49999168 0.1        0.02000015]
# nabla f(x 80 )=  [-1.6645553e-05  0.0000000e+00  7.5041537e-06]
# norm(nabla f(x 80 )=  1.8258881609112238e-05
#
#  x 81 = [0.49999332 0.1        0.01999941]
# nabla f(x 81 )=  [-1.33519068e-05  0.00000000e+00 -2.96169136e-05]
# norm(nabla f(x 81 )=  3.248745888022565e-05
#
#  x 82 = [0.49999364 0.1        0.02000011]
# nabla f(x 82 )=  [-1.27144675e-05  0.00000000e+00  5.73194042e-06]
# norm(nabla f(x 82 )=  1.3946785436154321e-05
#
#  x 83 = [0.4999949  0.1        0.01999955]
# nabla f(x 83 )=  [-1.01986629e-05  0.00000000e+00 -2.26224556e-05]
# norm(nabla f(x 83 )=  2.481508057636009e-05
#
#  x 84 = [0.49999514 0.1        0.02000009]
# nabla f(x 84 )=  [-9.71176404e-06  0.00000000e+00  4.37826067e-06]
# norm(nabla f(x 84 )=  1.0653052479720318e-05
#
#  x 85 = [0.4999961  0.1        0.01999965]
# nabla f(x 85 )=  [-7.79010272e-06  0.00000000e+00 -1.72798390e-05]
# norm(nabla f(x 85 )=  1.8954644199434406e-05
#
#  x 86 = [0.49999629 0.1        0.02000007]
# nabla f(x 86 )=  [-7.41819199e-06  0.00000000e+00  3.34427176e-06]
# norm(nabla f(x 86 )=  8.137181693627063e-06

# %%
#Algoritma umum

x=np.array([0,0,0]) #nilai awal
alpha=0.1  #coba kombinasi (0,0,1) , (0,0,0.1), (0,0,0.5), (1,1,1) , (1,1,0.1), (1,1,0.5)
print("x0= ",x)
nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1]) #menghitung nabla f(x) dengan x awal

print("nabla f(x0)= ",nablaf)
print("norm(nabla f(x0))= ",np.linalg.norm(nablaf))
error=0.00001

iter=1
maxiter=200

while  np.linalg.norm(nablaf)>error and iter<maxiter:
  x=x-alpha*nablaf #memperbaharui x
  nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1]) #menghitung nabla f(x) yang baru dengan x baru
  if(iter%5==0):
    print("\n","x",iter,"= ",x)
    print("nabla f(x",iter,")= ",nablaf)
    print("norm(nabla f(x",iter,")= ",np.linalg.norm(nablaf))
  iter=iter+1

print("\n","x",iter-1,"= ",x)
print("nabla f(x",iter-1,")= ",nablaf)
print("norm(nabla f(x",iter-1,")= ",np.linalg.norm(nablaf))

fx=np.array([x[0]**2+5*x[1]**2+25*x[2]**2-x[0]-x[1]-x[2]])
print("minumum f(x)=",fx)

# %%
#Metode Newton

x=np.array([0,0,0]) #nilai awal
print("x0= ",x)
nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1]) #menghitung nabla f(x) dengan x awal
nabla2f=np.array([[2,0,0],[0,10,0],[0,0,50]]) #kebetulan konstan, tidak bergantung pada x
print("nabla f(x0)= ",nablaf)
print("norm(nabla f(x0))= ",np.linalg.norm(nablaf))
error=0.00001

iter=1
maxiter=100

while  np.linalg.norm(nablaf)>error and iter<maxiter:
  x=x-np.linalg.inv(nabla2f)@nablaf #memperbaharui x
  print("\n","x",iter,"= ",x)
  nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1]) #menghitung nabla f(x) dengan x awal
  nabla2f=np.array([[2,0,0],[0,10,0],[0,0,10]]) #kebetulan konstan, tidak bergantung pada x
  print("nabla f(x",iter,")= ",nablaf)
  print("norm(nabla f(x",iter,")= ",np.linalg.norm(nablaf))
  iter=iter+1
# Out:
# x0=  [0 0 0]
# nabla f(x0)=  [-1 -1 -1]
# norm(nabla f(x0))=  1.7320508075688772
#
#  x 1 =  [0.5  0.1  0.02]
# nabla f(x 1 )=  [0. 0. 0.]
# norm(nabla f(x 1 )=  0.0

# %%
#Metode Conjugate Gradient

x=np.array([0,0,0]) #nilai awal
print("x0= ",x)
nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1]) #menghitung nabla f(x) dengan x awal
print("norm(nabla f(x0))= ",np.linalg.norm(nablaf))
nabla2f=np.array([[2,0,0],[0,10,0],[0,0,50]])
d=-nablaf #menghitung d

iter=1
maxiter=100
error=0.000001

while  np.linalg.norm(nablaf)>error and iter<maxiter:
  alpha=-d@nablaf/(d@nabla2f@d)
  x=x+alpha*d
  print("x",iter,"= ", x)
  nablaf=np.array([2*x[0]-1,10*x[1]-1,50*x[2]-1])
  print("norm(nabla f(x",iter,"))= ",np.linalg.norm(nablaf)) 
  d=-nablaf+( nabla2f@nablaf@d/(d@nabla2f@d)  )*d
  iter=iter+1
